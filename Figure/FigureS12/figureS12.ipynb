# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib

params = {'font.family': 'Arial','font.weight':'normal'} #set the basic parameters for figure
plt.rcParams["figure.dpi"] = 300
matplotlib.rcParams.update(params)

# %%
readdata_dir = "D:/Develop/Compensatory-Evolution/CodeForGithub/File/"
savedata_dir = "D:/Develop/Compensatory-Evolution/CodeForGithub/FigureS12/"

# %%
#show that it is also good for the DL model to predict the brightness of GFP
gfp_fidata = pd.read_csv(readdata_dir+"DeepLearningWeights/GFP/SingleAlleleFP_WTBrigntess.tsv", sep = "\t")
gfp_fidata
# Out:
#         sub  num_pair  diff_skewness  diff_median_diff  brightness sub_name  \
# 0     SY37N        32       1.182821          0.116826    3.862983      37N
# 1    SV161G        11      -0.316283          0.111908    3.657129     161G
# 2    SV161A       104       3.514737          0.098646    3.833021     161A
# 3     SY37C        56       0.065146          0.088294    3.769936      37C
# 4    SA204V        12       0.034557          0.085845    3.855894     204V
# ..      ...       ...            ...               ...         ...      ...
# 590   SR94H        11       0.447587         -2.304402    1.301065      94H
# 591  SL218P        34       3.160305         -2.322643    1.304706     218P
# 592  SL123P        28       2.363174         -2.335314    1.304080     123P
# 593   SY64N        12       1.505002         -2.341468    1.301031      64N
# 594   SV59E        20       3.586353         -2.348937    1.309476      59E
#
#          FP_WT
# 0     1.167775
# 1     1.141931
# ...

# %%
plt.figure(figsize=(3.5,3))
ax = plt.subplot(111)
plt.scatter(gfp_fidata["FP_WT"].values,
           gfp_fidata["brightness"].values)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
for axis in ['bottom','left']:
    ax.spines[axis].set_linewidth(0.5)
plt.xlabel("Fitness impact score of single A.A. state\n(predicted,neural network model fit to data)",fontsize = 11)
plt.ylabel("Measured brightness of mutants\nwith single substutiton",fontsize = 12)
plt.xticks(fontsize = 10)
plt.yticks(fontsize = 10)
plt.tight_layout()
plt.savefig(savedata_dir + "BindingEnergyRescuing.png", dpi = 300)
